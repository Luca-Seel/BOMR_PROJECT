# %%
# !pip install scipy numpy
# Out:
# Requirement already satisfied: scipy in /home/lucas/Anaconda3/lib/python3.13/site-packages (1.15.3)
# Requirement already satisfied: numpy in /home/lucas/Anaconda3/lib/python3.13/site-packages (2.1.3)

# %%
import heapq
import math as m
import numpy as np
from scipy.ndimage import distance_transform_edt
import global_nav as gb

# %%
# for debugging only 
import random 
from PIL import Image

# %%
# get a map somehow. For debugging I used a random generated map
env_map = gb.debug_generate_maze(100, 100, n_blobs= 4, blob_size=10)
gb.debug_maze_to_bitmap(env_map, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
gb.debug_maze_to_bitmap(gb.obstacle_scale(env_map=env_map, scale=10), cell_size=10)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
path = gb.a_star(env_map, m.pi, cm_px_scale=10) # map scale is in cm/px
# Out:
# ALL INDEXES ARE : 14, 94, (14, 94)
# ALL INDEXES ARE : 14, 95, (14, 95)
# ALL INDEXES ARE : 14, 96, (14, 96)
# ALL INDEXES ARE : 13, 98, (13, 98)
# ALL INDEXES ARE : 14, 97, (14, 97)
# ALL INDEXES ARE : 13, 99, (13, 99)
# ALL INDEXES ARE : 14, 98, (14, 98)
# ALL INDEXES ARE : 18, 98, (18, 98)
# ALL INDEXES ARE : 17, 98, (17, 98)
# ALL INDEXES ARE : 17, 98, (17, 98)
# ALL INDEXES ARE : 17, 98, (17, 98)
# ALL INDEXES ARE : 18, 99, (18, 99)
# ALL INDEXES ARE : 15, 99, (15, 99)
# ALL INDEXES ARE : 16, 99, (16, 99)
# ALL INDEXES ARE : 14, 99, (14, 99)
# ALL INDEXES ARE : 16, 99, (16, 99)
# ALL INDEXES ARE : 17, 99, (17, 99)
# ALL INDEXES ARE : 15, 99, (15, 99)
# 2198

# %% [markdown]
# The path returns as follows :
# [start, 1st move, 2nd move, ..., end ]
# where every cell is a tuple (x, y)

# %%
solved_map = env_map.copy()
for i in path : 
    solved_map[i[0]][i[1]] = -4 # marker for path in my debug functions
gb.debug_maze_to_bitmap(solved_map, 20)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000>

# %% [markdown]
# TO DO List  :
# 1. Stop using random maps and start using more realistic ones to test
# 2. account for robot size in path planning
# 3. account for robot orientation in path planning
